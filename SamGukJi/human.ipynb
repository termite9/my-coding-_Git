# %%
import json

# 삼국지 인물 데이터베이스
# 형식: { "인물명": ["주군", "역할"] }
# 예시 데이터를 포함합니다. 필요에 따라 더 많은 인물을 추가하거나 수정할 수 있습니다.
samgukji_characters = {
    "유비": ["유비", "촉한의 군주"],
    "관우": ["유비", "오호대장군, 용맹한 장수"],
    "장비": ["유비", "오호대장군, 용맹한 장수"],
    "제갈량": ["유비", "촉한의 승상, 책략가"],
    "조운": ["유비", "오호대장군, 충성스러운 장수"],
    "강유": ["제갈량", "촉한의 장수, 제갈량의 후계자"],
    "조조": ["조조", "위나라의 군주"],
    "하후돈": ["조조", "위나라의 장수, 조조의 심복"],
    "곽가": ["조조", "위나라의 책사"],
    "순욱": ["조조", "위나라의 책사"],
    "장료": ["조조", "위나라의 장수"],
    "손권": ["손권", "오나라의 군주"],
    "주유": ["손권", "오나라의 대도독, 책략가"],
    "육손": ["손권", "오나라의 대도독, 책략가"],
    "태사자": ["손권", "오나라의 장수"],
    "여몽": ["손권", "오나라의 장수"],
    "동탁": ["동탁", "후한 말의 폭군"],
    "여포": ["동탁", "최고의 무력을 지닌 장수, 여러 주군을 섬김"],
    "초선": ["왕윤", "미인계의 주인공"],
    "원소": ["원소", "하북의 제후"],
    "장각": ["황건적", "황건적의 난 주도자"],
    "전위": ["조조", "조조의 호위무사"],
    "허저": ["조조", "조조의 호위무사"],
    "방통": ["유비", "촉한의 책략가, 봉추"],
    "황충": ["유비", "오호대장군, 노장"],
    "마초": ["유비", "오호대장군, 서량의 맹장"],
    "위연": ["유비", "촉한의 장수"],
    "서황": ["조조", "위나라의 장수"],
    "장합": ["조조", "위나라의 장수"],
    "감녕": ["손권", "오나라의 장수"],
    "황개": ["손권", "오나라의 노장"],
    "정욱": ["조조", "위나라의 책사"]
}

# JSON 파일로 저장
# ensure_ascii=False는 한글이 깨지지 않도록 합니다.
# indent=4는 JSON 파일을 보기 좋게 들여쓰기합니다.
with open('characters.json', 'w', encoding='utf-8') as f:
    json.dump(samgukji_characters, f, ensure_ascii=False, indent=4)

print("samgukji_characters.json 파일이 성공적으로 생성되었습니다. 🎉")
# Out:
# samgukji_characters.json 파일이 성공적으로 생성되었습니다. 🎉
